# %% [markdown]
# DAY 3

# %%
#integer
s=12
print(s)
print(type(s))

#string
s="Hello"   
print(s)
print(type(s))

#float
s=3.14
print(s)
print(type(s))

#boolean
s=True  
print(s)
print(type(s))

#complex
s=2+3j
print(s)
print(type(s))

#none
s=None  
print(s)
print(type(s))

# %%
#list
#list is a collectuion of elements which are ordered, changeable and allows duplicate values
s=[1, 2, 3, 4, 5]   
print(s)
print(type(s))
print(len(s))
print(s[4])
print(s[-1])
#update list
s[2]='hello' 
print(s)
#delete specific element
del s[1]
print(s)
#delete entire list
del s
#print(s)  # This will raise an error since s is deleted




#tuple
s=(1, 2, 3, 4, 5)
print(s)
print(type(s))
print(len(s))
print(s[4])
print(s[-1])
# #update tuple
# # s[2]='hello'   This will raise an error since tuples are immutable
# print(s)
# #delete specific element
# del s[1]  This will raise an error since tuples are immutable
# print(s)
#delete entire tuple
del s


#set
s={1, 2, 3, 4, 5}
print(s)
print(type(s))
print(len(s))
#hashable elements
print(hash(3))
#update set
s.add(6)
print(s)
s.update([7, 8, 9])
print(s)
#delete specific element
s.remove(3)
print(s)
#delete entire set
del s


#dictionary
s={'name': 'Alice', 'age': 30, 'city': 'New York','place':{""}}
print(s)
print(type(s))
print(len(s))
print(s['name'])
#update dictionary
s['age']=31
print(s)
s['country']='USA'
print(s)
#delete specific element
del s['city']
print(s)
#delete entire dictionary
del s


#boolean
s=True
print(s)
print(type(s))  


#none
s=None  
print(s)
print(type(s))

# %% [markdown]
# DAY 4

# %% [markdown]
# Primitive & non-Primitive

# %%
#primitive data types

# integers, floats, strings, booleans, complex numbers, and None are all examples for premitive data type in python.

x=10 
x=24
print(x) # This will print the last assigned value of x, which is 24 
#always it will take a new memory location for the new value of x and the old value will be garbage collected.
#it is called as immutable data type because it cannot be changed after it is created.

# %%
#non-primitive data types

#list, tuple, set, and dictionary are examples for non-primitive data types in python.

s=[1, 2, 3, 4, 5]
print(s)
# Update lis
s[2] = 10
print(s) #it will update the value at index 2 to 10, 
#and the list will be modified in place without creating a new memory location and it is called as mutable data type.

# %% [markdown]
# OPERATORS TYPES

# %%
# Arithmetic operators --------> +,-,*,/,%,//,**
# assignment operators --------> =, +=, -=, *=, /=, %=, //=, **=
# logical operators    --------> and, or, not
# comparison operators --------> ==, !=, >, <, >=, <=
# identity operators   --------> is, is not
# membership operators --------> in, not in
# bitwise operators    --------> &, |, ^, ~, <<, >> 
# ternary operators    --------> value_if_true if condition else value_if_false


#arithmetic operators
a=10
b=3
print(a+b)  # Addition
print(a-b)  # Subtraction   
print(a*b)  # Multiplication
print(a/b)  # Division
print(a%b)  # Modulus
print(a//b) # Floor Division
print(a**b) # Exponentiation
print('hello' + 'world') # String concatenation using + operator
print('hello' * 3) # String repetition using * operator


#ASSIGNMENT OPERATORS
a=10
a+=5  # Equivalent to a = a + 5
print(a)  # Output: 15
a=10
a-=3  # Equivalent to a = a - 3
print(a)  # Output: 7
a=10
a*=2  # Equivalent to a = a * 2
print(a)  # Output: 20
a=10
a/=4  # Equivalent to a = a / 4
print(a)  # Output: 2.5
a=10
a%=3  # Equivalent to a = a % 3
print(a)  # Output: 1
a=10
a//=3  # Equivalent to a = a // 3
print(a)  # Output: 3
a=10
a**=2  # Equivalent to a = a ** 2
print(a)  # Output: 100

# %%
# LOGICAL OPERATORS
a = True
b = False
print(a and b)  # Logical AND
print(a or b)   # Logical OR
print(not a)    # Logical NOT

print(125 and True)
print("" and True)
print(0 and True)
print(-1 and 2)   #two truthy values will return the second truth value
print(None and 4)  #one falsy value & one truthy value will return the first falsy value
print([] and ())   #two falsy values will return the first falsy value
print([1,2,3] and (1,2,3))


#or
print(125 or True)
print("" or True)
print(0 or True)
print(-1 or 2)   
print(None or 4)  
print([] or ())   


# not
print(not True)   # Output: False
print(not False)  # Output: True    
print(not[1,2] and (2,4)) # Output: False
print(not 5) # Output: False (since 5 is a truthy value)
print(not 0) # Output: True (since 0 is a falsy value)
print(not None) # Output: True (since None is a falsy value)
print(not "") # Output: True (since an empty string is a falsy value)

# %%
#relational operators
a=10
b=20
print(a==b)  # Equal to
print(a!=b)  # Not equal to
print(a> b)  # Greater than
print(a< b)  # Less than
print(a>=b)  # Greater than or equal to
print(a<=b)  # Less than or equal to

print((1==1) and (2==2))  # Output: True
print("hello"=="hello")  # Output: True
print("hello"=="Hello")  # Output: False (case-sensitive)

# %%
#Identity operators
a = [1, 2, 3]
b = [1,2,3]
print(a is b)  # Output: False (a and b are different objects in memory)
print(a == b)  # Output: True (a and b have the same content)

print(a is not b)  # Output: True (a and b are different objects in memory)
print(a != b)      # Output: False (a and b have the same content)

# %%
# membership operators
str="Hello, welcome to Python programming!"
print('welcome' in str)  # Output: True
print('Java' in str)     # Output: False

print('java' not in str)  # Output: True

list1 = [1, 2, 3, 4, 5]
print(3 in list1)  # Output: True
print(6 not in list1)  # Output: True

dist={'name': 'Alice', 'age': 30, 'city': 'New York'}
print('name' in dist)  # Output: True (checks if 'name' is a key in the dictionary)
print('Alice' in dist)  # Output: False (checks if 'Alice' is a key in the dictionary, which is not the case)

# %%
# bitwise operators
a = 5  # In binary: 0101
b = 3  # In binary: 0011    
print(a & b)  # Bitwise AND: 0101 & 0011 = 0001 (1 in decimal)
print(a | b)  # Bitwise OR: 0101 | 0011 = 0111 (7 in decimal)
print(a ^ b)  # Bitwise XOR: 0101 ^ 0011 = 0110 (6 in decimal)
print(~a)     # Bitwise NOT: ~0101 = 1010 (in
print(a << 1) # Bitwise left shift: 0101 << 1 = 1010 (10 in decimal)
print(a >> 1) # Bitwise right shift: 0101 >> 1 = 0010 (2 in decimal)

# %%
# ternary operator
num=int(input("Enter a number: "))
res='even number' if(num & 1 == 0) else 'odd number'
print(res)

# #login system using ternary operator
input_username=input("Enter your username: ")
input_password=input("Enter your password: ")
username='INDIAN'
password='INDIA@123'
logic='successfully logind' if (input_username == username and input_password == password) else 'invalid credientials'
print(logic)

#postive number or negative number using ternary operator
num=int(input("Enter a number: "))
res='positive number' if (num > 0) else 'negative number' 
print(res)

# %%
#list
x=[10,20,33,44,53,65,87,78,90,32,45,67,89,90]
# for i in x:
#     print(i)  # This will raise an error since i is an integer and does not support indexing
 
for y in range(len(x)-1,-1,-1):
    print(x[y])


# # Deictionary
# s={'name': 'Alice', 'age': 30, 'city': 'New York'}
# for i in s:
#     # print(f'{i}: {s[i]}')
#     # print(s[i])
#     print(i)

# %%
count=0
for i in range(1,51):
    if i % 3 == 0 or i % 5 == 0:
        count += 1
        print(f'{i}--{count}')

print('total count:', count)

# %%
# even=0
# # odd=1 
# # for i in range(1,31):
# #     if i % 2 == 0:
# #         even += i
# #     else:
# #         odd *=i

# # print('sum of even numbers:', even)
# # print('product of odd numbers:', odd)


# recharge=30
# while recharge >= 1:
#     recharge -=1
#     print(f'{recharge}-days left')
#     if recharge == 1:
#         print('Do recharge sim will not work')

#         break


str1='something'
x=0
count = 0
while x < len(str1):
    if str1[x-1] in 'aeiouAEIOU':
        print(f'{str1[x-1]} is a vowel')
        x += 1
        count += 1
    else:
        x += 1
    
print(f'vowel count: {count}')


# x=len(str1)-1
# while x >= 0:
#     print(str1[x])
#     x-=1

# %%
v=int(input("Enter a number: "))
d=v
r=0
while v > 0:
    result=v % 10
    r = r*10 + result  
    v //=10
if d==r:
    print("It is a palindrome number")
else:
    print("It is not a palindrome number")

# %% [markdown]
# Practice Day-2

# %%
#equilateral triangle
#triangle
#isosceles triangle
#scalene triangle

a=int(input("Enter the first side of triangle: "))
b=int(input("Enter the second side of triangle: "))
c=int(input("Enter the third side of triangle: "))
if a+b+c==180:
    print(f'{a} & {b} & {c} is a triangle of {a+b+c}')

    if a==b==c:
        print('it is an equilateral triangle ')
    elif a==b or b==c or c==a:
        print('it is an isosceles triangle')
    else:
        print('it is a scalene triangle')
else:
    print('it is not a triangle')

# %%
temperature=int(input("Enter the temperature in celsius: "))
if temperature > 0 :
    if temperature <= 30:
        print(f'the temperature {temperature} is Modrate')
    elif temperature > 30 and temperature <= 50:
        print(f'the temperature {temperature} is hot')
    else:
        print(f'the temperature {temperature} is too hot. It is not a good to go outside')
else:
    print(f'the temperature {temperature} is freezing point')

# %% [markdown]
# 26-2-2026

# %%
str1="DATA"
for i in str1:
    print(f'{i}-Hello')

# %%
list1=[4,6,8,2,3,1,8,9]
for i in list1:
    print(f'square of {i} is {i**2}')

# %%
var='SOMETHING IS FISHY'
v=1
for i in var:
    print(i,var[v])
    v+=1

# %%
n=['shiva','karthik','ravi']
for i in n:
    print(f'length of {i} is {len(i)}')

# %%
nums=[3,5,7,8,2,4,6,10]
x=0
for i in nums:
    print(f"{i} multplied by {x} = {i*x}")
    x+=1

# %%
str1=input('Enter name:')
dict1={}
for i in str1:
    if i in dict1:
        dict1[i]+=1
    else:
        dict1[i]=1
print(dict1)

# %%
# list1=['apple','banana','some','hello','welcome','oops']
list1='soMetHINg'
l=[]                                      #l=''                                   
for i in list1:
    if (i==i.upper()):
        # print(f'{i.lower()}')
        # l+=[i.lower()]
                                          l+=i.lower()
    else:
        # print(f'{i.upper()}')
        # l+=[i.upper()]
                                          l+=i.upper()
print(l)

# %%
num=int(input('Enter number:'))
c=1
for i in range(num,0,-1):
    c*=i
print(c)

# %%
ecommerce_data = [
    {
        "order_id": "O1001",
        "customer_name": "Ravi Kumar",
        "city": "Hyderabad",
        "product": "Wireless Mouse",
        "category": "Electronics",
        "price": 799,
        "quantity": 2,
        "total_amount": 1598,
        "payment_method": "UPI",
        "order_status": "Delivered"
    },
    {
        "order_id": "O1002",
        "customer_name": "Sneha Reddy",
        "city": "Bangalore",
        "product": "Bluetooth Headphones",
        "category": "Electronics",
        "price": 1999,
        "quantity": 1,
        "total_amount": 1999,
        "payment_method": "Credit Card",
        "order_status": "Shipped"
    },
    {
        "order_id": "O1003",
        "customer_name": "Arjun Singh",
        "city": "Mumbai",
        "product": "Running Shoes",
        "category": "Fashion",
        "price": 2499,
        "quantity": 1,
        "total_amount": 2499,
        "payment_method": "Cash on Delivery",
        "order_status": "Processing"
    },
    {
        "order_id": "O1004",
        "customer_name": "Priya Sharma",
        "city": "Delhi",
        "product": "Smart Watch",
        "category": "Electronics",
        "price": 3499,
        "quantity": 1,
        "total_amount": 3499,
        "payment_method": "Debit Card",
        "order_status": "Delivered"
    },
    {
        "order_id": "O1005",
        "customer_name": "Kiran Patel",
        "city": "Chennai",
        "product": "Laptop Backpack",
        "category": "Accessories",
        "price": 1299,
        "quantity": 3,
        "total_amount": 3897,
        "payment_method": "UPI",
        "order_status": "Shipped"
    }
]



# for x in ecommerce_data:
# #     if x["customer_name"] == x['customer_name']:
# #         print(x['customer_name'])
#        if x['price'] > 1000:
#               print(x['customer_name'], x['price'])


#print custoer names who is using upi method
#print customer names who is purchasing other than electronics category
#print customer names who is purchasing more than 1 quantity

for x in ecommerce_data:
    if x["payment_method"]=='UPI':
        print(x['customer_name'],x["payment_method"])

    if x['category'] != "Electronics":
         print(x['customer_name'],x["category"])

    if x["quantity"]>1:
        print(x['customer_name'],x["quantity"])

# %%
# strong number
num=int(input("Enter a number: "))
we=num
s=0
while we > 0:
    result=we%10
    fact=1
    for i in range(result,0,-1):
        fact*=i
        s+=fact
        we//=10
if s == num:
    print("Strong number")
else:
    print("Not a strong number")

# %%
def palandrom(x):
    c=x
    if isinstance(x,int):
        # print('it is an integer')
        rev=0
        while x > 0:
            ld=x%10
            rev=rev*10+ld
            x=x//10
        print(rev)
        if c == rev:
            print('It is a palandrom')
        else:
            print('It is not a palandrom')
    else:
        # print('x is not integer')
        rev=''
        for i in range(len(x)-1,-1,-1):
            rev+=x[i]
        print(rev)
        if c == rev:
            print('It is a palandrom')
        else:
            print('It is not a palandrom')

palandrom(123)
palandrom(121)
palandrom('level')
palandrom('bomb')
# Out:
# 321
# It is not a palandrom
# 121
# It is a palandrom
# level
# It is a palandrom
# bmob
# It is not a palandrom

# %%
def perfect_number(n):
    i=1
    sum=0
    while i < n:
        if n % i == 0:
            sum+=i
        i+=1
    if sum == n:
        print('It is a perfect number')
    else:
        print('It is not a perfect number')

perfect_number(5)  
perfect_number(28)
# Out:
# It is not a perfect number
# It is a perfect number

# %%
def perfect_square(n):
    c=1
    is_perfect_square=False
    while c < n:
        if c*c == n:
            is_perfect_square=True
        c+=1
    if is_perfect_square== True:
        print(f"{n} is perfect square")
    else:
        print(f"{n} is not perfect square")
      
perfect_square(9)
# Out:
# 9 is perfect square

# %%
def perfect_number(n):
        i=1
        sum=0
        while i < n:
            if n % i == 0:
                sum+=i
            i+=1
        if sum == n:
            print('It is a perfect number')
        else:
            print('It is not a perfect number')

def perfect_square(n):
    c=1
    is_perfect_square=False
    while c < n:
        if c*c == n:
            is_perfect_square=True
            c+=1
        if is_perfect_square== True:
            print(f"{n} is perfect square")
        else:
            print(f"{n} is not perfect square")

x=input("Enter perfect number or perfect square: ")
if x == "perfect_number":
    perfect_number(int(input("Enter a number: ")))  
elif x == "perfect_square":
    perfect_square(int(input("Enter a number: ")))
else:
    print("Invalid input. Please enter 'perfect_number' or 'perfect_square'.")
# Out:
# It is a perfect number

# %%
# prime number

n=10
m=20
v=0
for i in range(n,m+1):
    count=0
    for j in range(1,i+1):
        if i % j == 0:
            count+=1
    if count == 2:
        v+=1
print (v)
# Out:
# 4

# %% [markdown]
# Object orented programing system(oops)

# %%
class student:
    id=101
    name='shiva'
    age=22
    place='hyderabad'
    def eat(self):
        print('eating......')
    def sleep(self):
        print('sleeping.....')
s1=student()
print(s1.id)
print(s1.name)
print(s1.age)
print(s1.place)
s1.eat()
s1.sleep()
# Out:
# 101
# shiva
# 22
# hyderabad
# eating......
# sleeping.....

# %%
class student:
    def info(self,id,name,age,place):
        self.id=id
        self.name=name
        self.age=age
        self.place=place    
    def eat(self):
        print(self.name,'eating......')
    def sleep(self):    
        print(self.name,'sleeping.....')
s1=student()
s1.info(101,'shiva',22,'hyderabad')
s1.eat()
s1.sleep()
s1.info(102,'Ajay',23,'bangalore')
s1.eat()
s1.sleep()
# Out:
# shiva eating......
# shiva sleeping.....
# Ajay eating......
# Ajay sleeping.....

# %%
class employee:
    def __init__(self,id,name,salary,Experience):
        self.id=id
        self.name=name
        self.salary=salary
        self.Experience=Experience
    def info(self):
        print('id of employee:',self.id)
        print('name of employee:',self.name)
        print('salary of employee:',self.salary)
        print('experience of employee:',self.Experience)
    def work(self):
        print(self.name,'is working.....')
    def exp(self):
        print(self.name,'has',self.Experience,'years of experience')

s1=employee(101,'shiva',50000,2)
s1.info()
s1.work()
s1.exp()
print('-'*22)
s2=employee(102,'Ajay',60000,3)
s2.info()
s2.work()
s2.exp()
# Out:
# id of employee: 101
# name of employee: shiva
# salary of employee: 50000
# experience of employee: 2
# shiva is working.....
# shiva has 2 years of experience
# ----------------------
# id of employee: 102
# name of employee: Ajay
# salary of employee: 60000
# experience of employee: 3
# Ajay is working.....
# Ajay has 3 years of experience

# %%
class Vehicles:
    def details(self,car_name,car_colour,car_price,car_mileage):
        self.car_name=car_name
        self.car_colour=car_colour
        self.car_price=car_price    
        self.car_mileage=car_mileage
    def info(self):
        print('car name is :',self.car_name)
        print('car colour is :',self.car_colour)
        print('car price is :',self.car_price)
        print('car mileage is :',self.car_mileage)
    def start(self):
        print('car is started')
    def stop(self):
        print('car is stopped')
    def turn_on_ac(self):
        print('ac is turned on')
    def turn_off_ac(self):
        print('ac is turned off')
c=Vehicles()
c.details('BMW','black',5000000,10)
c.info()
c.start()
c.turn_on_ac()
c.stop()
c.turn_off_ac()
print('-----------------------------')
c=Vehicles()
c.details('Tata_Safari','Blue',2500000,16)
c.info()
c.start()
c.turn_on_ac()
c.stop()
c.turn_off_ac()
# Out:
# car name is : BMW
# car colour is : black
# car price is : 5000000
# car milage is : 10
# car is started
# ac is turned on
# car is stopped
# ac is turned off
# -----------------------------
# car name is : Tata_Safari
# car colour is : Blue
# car price is : 2500000
# car milage is : 16
# car is started
# ac is turned on
# car is stopped
# ac is turned off

# %% [markdown]
# Constrains used

# %%
class cars:
    def __init__(self,car_name,car_colour,car_price,car_milage,current_speed):
        self.car_name=car_name
        self.car_colour=car_colour
        self.car_price=car_price    
        self.car_milage=car_milage
        self.current_speed=current_speed
    def info(self):
        print('car name is :',self.car_name)
        print('car colour is :',self.car_colour)
        print('car price is :',self.car_price)
        print('car milage is :',self.car_milage)
        print('current speed is :',self.current_speed)
    def start(self):
        print(f'{self.car_name} is started.....')
    def accelerate(self,current_speed):
        if current_speed >= 100: 
            print(f'{self.car_name} is at maximum speed')
        else:
            self.current_speed += 10
            print(f'{self.car_name} is accelerating, current speed is {self.current_speed}')
    def brake(self,current_speed):
        if self.current_speed == 0:
            print(f'{self.car_name} is stoped')
        else:
            self.current_speed -= 10
            print(f'{self.car_name} is decelerating, current speed is {self.current_speed}') 
    def stop(self):
        print(f'{self.car_name} is stopped.....')

c2=cars('BMW','black',5000000,10,50)
c2.info()
c2.start()
c2.accelerate(c2.current_speed)
c2.accelerate(c2.current_speed)
c2.accelerate(c2.current_speed)
c2.accelerate(c2.current_speed)
c2.accelerate(c2.current_speed)
c2.accelerate(c2.current_speed)
c2.brake(c2.current_speed)
c2.brake(c2.current_speed)  
c2.brake(c2.current_speed)
c2.brake(c2.current_speed)
c2.brake(c2.current_speed)
c2.brake(c2.current_speed)
c2.stop()
# Out:
# car name is : BMW
# car colour is : black
# car price is : 5000000
# car milage is : 10
# current speed is : 50
# BMW is started.....
# BMW is accelerating, current speed is 60
# BMW is accelerating, current speed is 70
# BMW is accelerating, current speed is 80
# BMW is accelerating, current speed is 90
# BMW is accelerating, current speed is 100
# BMW is at maximum speed
# BMW is decelerating, current speed is 90
# BMW is decelerating, current speed is 80
# BMW is decelerating, current speed is 70
# BMW is decelerating, current speed is 60
# BMW is decelerating, current speed is 50
# BMW is decelerating, current speed is 40
# BMW is stopped.....

# %% [markdown]
# INHERITANCES

# %%
class Basic_calculator:
    def add(self,a,b):
        print(a+b)
    def subtract(self,a,b):
        print(a-b)  
    def multiply(self,a,b):
        print(a*b)
class Scientific_calculator(Basic_calculator):
    def power(self,a,b):
        print(a**b)
    def square_root(self,a):
        print(a**0.5)
class advanced_calculator(Scientific_calculator):
    def modulus(self,a,b):
        print(a%b)

B=advanced_calculator()
B.add(10,5)
B.subtract(10,5)
B.multiply(10,5)
B.power(10,5)
B.square_root(25)
B.modulus(10,3)
# Out:
# 15
# 5
# 50
# 100000
# 5.0
# 1

# %% [markdown]
# TYPES OF INHERITANCES

# %% [markdown]
# single-Level inheritance

# %%
class parent:
    def sleep(self):
        print('sleeping.....')
    def eat(self):
        print('eating.....')
class child(parent):
    def play(self):
        print('playing.....')
c=child()
c.sleep()
c.eat()
c.play()
# Out:
# sleeping.....
# eating.....
# playing.....

# %%
class software_engineer:    #parent_class/super/base class
    def __init__(self,id,name,salary,experience):
        self.id=id
        self.name=name
        self.salary=salary
        self.experience=experience
    def info(self):
        print('software engineer id is :',self.id)
        print('software engineer name is :',self.name)
        print('software engineer salary is :',self.salary)
        print('software engineer experience is :',self.experience)
    
class developer(software_engineer):  #child_class/sub/derived class
    def cooding(self):
        print(f'{self.name} is coding.....')
    def software(self):
        print(f'{self.name} is having software skills.....')

class tester(software_engineer): #child_class/sub/derived class
    def testing(self):
        print(f'{self.name} is testing.....')
    def debugging(self):
        print(self.name,'is doing debugging.....')

d=developer(2,'Karthik',60000,6)
d.info()
d.cooding()
print('-----------------------------')
t=tester(3,'Priya',55000,4)
t.info()    
t.debugging()
# Out:
# software engineer id is : 2
# software engineer name is : Karthik
# software engineer salary is : 60000
# software engineer experience is : 6
# Karthik is coding.....
# -----------------------------
# software engineer id is : 3
# software engineer name is : Priya
# software engineer salary is : 55000
# software engineer experience is : 4
# Priya is doing debugging.....

# %%
from abc import ABC, abstractmethod
class paymentprocess(ABC):
    @abstractmethod
    def pay(self,amount):
        pass
class upi(paymentprocess):
    def pay(self,amount):
        print(f'payment of {amount} is done using UPI')

class Debitcard(paymentprocess):
    def pay(self,amount):
        print(f'payment of {amount} is done using Debit card')

class netbanking(paymentprocess):
    def pay(self,amount):
        print(f'payment of {amount} is done using Net banking')

pp=upi()
pp.pay(1000)

dd=Debitcard()
dd.pay(2000)

nn=netbanking()
nn.pay(3000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       4     @abstractmethod
#       5     def pay(self,amount):
#       6         pass
# ----> 8 pp=paymentprocess()
#       9 pp.pay(1000)
#
# TypeError: Can't instantiate abstract class paymentprocess without an implementation for abstract method 'pay'

# %%
from abc import ABC, abstractmethod
class calculator(ABC):
    @abstractmethod
    def add(self,a,b):
        pass

    @abstractmethod
    def subtract(self,a,b):
        pass    

    @abstractmethod
    def multiply(self,a,b):
        pass

    @abstractmethod
    def divide(self,a,b):
        pass
class simplecalculator(calculator):
    def add(self,a,b):
        print(f'Sum of {a} and {b} is {a+b}')
    def subtract(self,a,b):
        print(f'Difference of {a} and {b} is {a-b}')
    def multiply(self,a,b):
        print(f'Product of {a} and {b} is {a*b}')
    def divide(self,a,b):
        if b != 0:
            print(f'Quotient of {a} and {b} is {a/b}')
        else:
            print("Cannot divide by zero")

sc=simplecalculator()
sc.add(10,5)
# Out:
# Sum of 10 and 5 is 15

# %%
n='aaaaabbbbddd'
val={}
count=0
for i in n:
    if i in val:
        val[i]+=1
    else:
        val[i]=1
     
print(val)
# Out:
# {'a': 5, 'b': 4, 'd': 3}

# %%
s='ab[5]bc[4]cd[3]de[2]'

re=''
dig=0
ch=''
for i in s:
    if i.isalpha():
        ch+=i
    elif i.isdigit():
        dig=int(i)
    elif i == ']':
        re+=ch*dig
print(re)
# Out:
# ababababababbcabbcabbcabbcabbccdabbccdabbccdabbccddeabbccdde
