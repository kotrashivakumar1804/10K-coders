# %%
lst=[1,2,1,2,3,4,5]
l=[]
d=[]
for i in lst:
    if i in l:
        d+=[i]
    else:
        l+=[i]
print(l)
# Out:
# [1, 2, 3, 4, 5]
# [1, 2]

# %%
lst=[1,2,1,2,5,6,4,7,3,4,5]
lis1=[]
duplicates=[]
unique=[]
for i in lst:
    if i not in lis1:
        lis1+=[i]
    else:
        duplicates+=[i]
for j in lis1:
    if j not in duplicates:
        unique+=[j]
print(lis1)
print(duplicates)
print(unique)
# Out:
# [1, 2, 5, 6, 4, 7, 3]
# [1, 2, 4, 5]
# [6, 7, 3]

# %%
lst=[1,2,1,2,5,6,4,7,3,4,5]
dup=[]
uniq=[]
for i in lst:
    count=0
    for j in lst:
        if i==j:
            count += 1
    if count >= 2:
        if i not in dup:
             dup+=[i]
    else:
        uniq+=[i]
print(dup)
print(uniq)
# Out:
# [1, 2, 5, 4]
# [6, 7, 3]

# %%
lst=[1,2,1,2,5,6,4,7,3,4,5]
lst1=lst.copy()
lst1.append(5555)
print(lst)
print(lst1)
# Out:
# [1, 2, 1, 2, 5, 6, 4, 7, 3, 4, 5]
# [1, 2, 1, 2, 5, 6, 4, 7, 3, 4, 5, 5555]

# %%
import copy
lst=[1,2,1,[2,5,6,4],7,3,[4,5]]
lst1=copy.deepcopy(lst) 
lst1[2].append(6)
print(lst)
print(lst1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       2 lst=[1,2,1,[2,5,6,4],7,3,[4,5]]
#       3 lst1=copy.deepcopy(lst)
# ----> 4 lst1[2].append(6)
#       5 print(lst)
#       6 print(lst1)
#
# AttributeError: 'int' object has no attribute 'append'

# %%
x=10
def fun(a):
    # global x
    # x=x+10
    return  a
x+=fun(10)
print(x)
# Out:
# 20

# %% [markdown]
# TASK in INHERATANCE

# %%
class Employee:
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary
    def display_details(self):
        print('employee name:',self.name)
        print('employee salary:',self.salary)
class Manager(Employee):
    def __init__(self, name, salary,team_size):
        super().__init__(name, salary)
        self.team_size=team_size
    def display_role(self):
        print('manager team size is', self.team_size)
class Engineer(Employee):
    def __init__(self, name, salary,specilization):
        super().__init__(name, salary)
        self.specilization=specilization
    def display_role(self):
        print('engineer specialization is', self.specilization)

mgr=Manager('alice',80000,10)
mgr.display_details()   
mgr.display_role()
print('-'*30)
eng=Engineer('bob',60000,'Python')
eng.display_details()
eng.display_role()
# Out:
# employee name: alice
# employee salary: 80000
# manager team size is 10
# ------------------------------
# employee name: bob
# employee salary: 60000
# engineer specialization is Python

# %%
class payment:
    def __init__(self,amount):
        self.amount=amount
    def process_payment(self):
        print('processing payment of amount:',self.amount)
class credit_card_payment(payment):
    def process_payment(self):
        print('processing credit card payment of amount:',self.amount)
class UPI_payment(payment):
    def process_payment(self):
        print('processing UPI payment of amount:',self.amount)
class net_banking_payment(payment):
    def process_payment(self):
        print('processing net banking payment of amount:',self.amount)

def make_payment(payment_method):
    payment_method.process_payment()

c=credit_card_payment(1000)
u=UPI_payment(200)
n=net_banking_payment(30000)
make_payment(c)
make_payment(u) 
make_payment(n)
# Out:
# processing credit card payment of amount: 1000
# processing UPI payment of amount: 200
# processing net banking payment of amount: 30000

# %%
class BankAccount:
    def __init__(self,__account_number, __balance):
        self.__account_number = __account_number
        self.__balance = __balance
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f'Deposited {amount}. New balance: {self.__balance}')
    def withdraw(self, amount):
        if amount > 0 and amount <= self.__balance:
            self.__balance -= amount
            print(f'Withdrew {amount}. New balance: {self.__balance}')
        else:
            print('Insufficient funds.')
    def get_balance(self):
        return f'Current balance: {self.__balance}'
    def get_account_number(self):
        return f'Account numbers is: {self.__account_number}'

acc=BankAccount('123456789', 1000)
acc.deposit(500)
acc.withdraw(200)
acc.withdraw(1500)
print(acc.get_account_number())
print(acc.get_balance())
# Out:
# Deposited 500. New balance: 1500
# Withdrew 200. New balance: 1300
# Insufficient funds.
# Account numbers is: 123456789
# Current balance: 1300

# %%
from abc import ABC, abstractmethod
class employee(ABC):
    def __init__(self,name):
        self.name=name
        self.salary=0
    def display_details(self):
        print('employee name:',self.name)
        print('employee salary:',self.salary)
    @abstractmethod
    def calculate_salary(self):
        pass

class Full_time_employee(employee):
    def __init__(self,name,monthly_salary):
        super().__init__(name)
        self.monthly_salary=monthly_salary
    def calculate_salary(self):
        self.salary=self.monthly_salary
        print(self.salary)
class Part_time_employee(employee):
    def __init__(self,name,hours_worked, hourly_rate):
        super().__init__(name)
        self.hours_worked=hours_worked
        self.hourly_rate=hourly_rate
    def calculate_salary(self):
        self.salary=self.hours_worked*self.hourly_rate
        print(self.salary)

ff=Full_time_employee('shiva', 5000)
pp=Part_time_employee('karan', 20, 15)
ff.calculate_salary()
pp.calculate_salary()
# Out:
# 5000
# 300

# %%
n=12345
def sum_of_digits(n):
    s=0
    while n > 0:
        r=n%10
        s+=r
        n//=10
    return s

while n > 9:
    n=sum_of_digits(n)
print(n)
# Out:
# 6

# %%
s1='hello'
s2='oellh'

# if len(s1) == len(s2):
#     if sorted(s1) == sorted(s2):
#         print('It is a Enagram')
#     else:
#         print('It is not a Enagram')
# else:
#     print('It is not a Enagram')



if len(s1) == len(s2):
    s2=list(s2)
    for i in s1:
        if i in s2:
            s2.remove(i)
            if len(s2) == 0:
                print('It is a Enagram')
        else:
            print('It is not a Enagram')
            break
else:
    print('It is not a Enagram')
# Out:
# It is a Enagram

# %%
print("Bank is started")
a=10
b=2
try:
    c=a//b
except Exception:
    print("An error occurred")
else:
    print(c)
finally:
    print("Bank is closed")
# Out:
# Bank is started
# An error occurred
# Bank is closed

# %% [markdown]
# 11-5-26

# %%
lst=[3,7,2,14,17]
res=[]
for i in lst:
    if i % 2 != 0:
        res+=[i]
print(res)
# Out:
# [3, 7, 17]

# %%
lst=[3,7,2,14,17]
res=[]
for i in lst:
    if i % 2 == 0:
        res+=[i]
print(res)
# Out:
# [2, 14]

# %%
k=[3,14,16,6,10]
res=[]
for i in k:
    i=i+1
    c=0
    for j in range(1,i+1):
        if i % j == 0:
            c+=1
    if c == 2:
        res+=[i]
print(res)
# Out:
# [17, 7, 11]

# %%
lst=[5,9,8,16,10]
l=[]
for i in lst:
    c=0
    for j in range(1,i+1):
        if i % j== 0:
            c+=1
    if c == 2:
        l+=[i]
    elif c == 3:
        l+=[i]
print(l)
# Out:
# [5, 9]

# %%
lst=[5,9,8,16,10]
res=[]
for n in lst:
    temp=n
    fact=0
    for i in range(1,temp+1):
        if temp % i == 0:
            fact+=1
    c=0
    for i in range(1,fact+1):
        if fact % i ==0 :
            c+=1
    if c==2:
        res.append(n)
print(res)
# Out:
# [5, 9, 16]

# %%
s='ab[5]bc[4]cd[3]de[2]'

re=''
dig=0
ch=''
for i in s:
    if i.isalpha():
        ch+=i
    elif i.isdigit():
        dig=int(i)
    elif i == ']':
        re+=ch*dig
print(re)

# %%
n='aaaaabbbbddd'
val={}
count=0
for i in n:
    if i in val:
        val[i]+=1
    else:
        val[i]=1
     
print(val)
# Out:
# {'a': 5, 'b': 4, 'd': 3}

# %% [markdown]
# 14-5-2026

# %%
l=[1,2,3]
for i in range(len(l)-1,-1,-1):
    if l[i] < 9:
        l[i] += 1
        break
    else:
        l[i] = 0
else:
    l.insert(0,1)
print(l)
# Out:
# [1, 2, 4]

# %%
lst=[7,0]
f=0
s=0
for i in lst:
    if i > f:
        s=f
        f=i
    elif i > s and i != f:
        s=i
if s == 0:
    print('there is no s max')
else:
    print('we found second max')
    
print(s)
# Out:
# there is no s max
# 0

# %%
l=[1,2,5,3,1,2,3,2,3]
res=[]
# for i in l:
#     c=0
#     for j in l:
#         if i == j:
#             c+=1
#     if c > 1:
#         if i not in res:
#             res.append(i)

for i in l:
    if l.count(i)>1:
        if i not in res:
            res.append(i)

print(res)
# Out:
# [1, 2, 3]

# %%
p='Password@123'
u=False
l=False
d=False
s=False
if len(p) >= 8:
    for i in p:
        if i.isupper():
            u=True
        elif i.islower():
            l=True
        elif i.isdigit():
            d=True
        else:
            s=True
    if u and l and d and s:
        print('True')
    else:
        print('False')
else:
    ('password must contain 8 characters')
# Out:
# True

# %% [markdown]
# Palandrome

# %%
n='madam'
c=''
for i in range(len(n)-1,-1,-1):
    c+=n[i]
if n == c:
    print('it is pallendrome')
else:
    print('not a palandrome')
# Out:
# it is pallendrome

# %% [markdown]
# 22-05-2026

# %%
n=int(input('enter any number:'))
if n % 5 == 0:
    if n % 10 != 0:
        print('satisyed')
    else:
        print('it was successfully divided by 10 so . it is not satisfied')
else:
    print('it was not successfully divided by 5 so . it is not satisfied')
# Out:
# it was successfully divided by 10 so . it is not satisfied

# %%
a=int(input('enter a number:'))
b=int(input('enter a number:'))
v= f'biggest number {b}' if a < b else f'biggest number {a}' 
print(v)

a=int(input('enter a number:'))
b=int(input('enter a number:'))
v= f'smallest number {a}' if a < b else f'smallest number {b}' 
print(v)

# if a > b or a < b:
#     if b < a :
#         print(f'{a} A is greater than {b} B')
#     elif b > a:
#         print(f'{b} B is greater than {a} A')
# Out:
# biggest number 7

# %%
a=int(input('enter a number:'))
b=int(input('enter a number:'))
v= f'smallest number {a}' if a < b else f'smallest number {b}' 
print(v)
# Out:
# smallest number 4

# %%
n=int(input('enter any number:'))
if (n % 2 and n % 3 and n % 6) == 0:
    print('satsfied')
else:
    print('not satsfied')
# Out:
# satsfied

# %%
age=int(input('Enter your age:'))
b="Elgible for vote" if age >= 18 else "not elgible for vote"
print(b)
# Out:
# Elgible for vote

# %%
#-----------------------student pass if got 35 marks in any subject----------------
# maths=int(input('enter marks'))
# physics=int(input('enter marks'))
# chemistry=int(input('enter marks'))
# if maths >= 35 or physics >= 35 or chemistry >= 35:
#     print(f'{maths} {physics} {chemistry} == pass')
# else:
#     print(f'{maths} {physics} {chemistry} == fail')

# v="pass" if maths >= 35 or physics >= 35 or chemistry >= 35 else "fail"
# print(v)

#--------------------------------------------student pass if 2 subjects have > 35 marks  or fail----------------
# maths=int(input('enter marks'))
# physics=int(input('enter marks'))
# chemistry=int(input('enter marks'))
# v="pass" if (maths >= 35 and physics >= 35) or (physics >= 35 and chemistry >= 35) or (maths >= 35 and chemistry >= 35) else "fail"
# print(v)


#------------- student pass if 3 subjects have > 35 marks  or fail------------------
# maths=int(input('enter marks'))
# physics=int(input('enter marks'))
# chemistry=int(input('enter marks'))
# v="pass" if maths >= 35 and physics >= 35 and chemistry >= 35 else "fail"
# print(v)
# Out:
# fail

# %%
#----------------------Biggest number amount 3 numbers----------------------------
a=int(input('enter a number:'))
b=int(input('enter a number:'))
c=int(input('enter a number:'))
# if a > b and a > c:
#     print(f'{a} A is greater than {b} B and {c} C')
# elif b > a and b > c:
#     print(f'{b} B is greater than {a} A and {c} C')
# elif c > a and c > b:
#     print(f'{c} C is greater than {a} A and {b} B')

b="grater number is A " if a>b and a>c else "grater number is B" if b>a and b>c else "grater number is C"
print(b)

n="smallest number is A " if a < b and a < c else "smallest number is B" if b < a and b < c else "smallest number is C"
print(b)

# %%
n=[('a', 3), ('b', 1), ('c', 2)]
y=''
for i, count in n:
    y+=i*count
print(y)
# Out:
# aaabcc
