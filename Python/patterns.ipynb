# %%
for i in range(3):
    print(i,end=' ')
# Out:
# 0 1 2

# %%
for x in range(3):
    for y in range(1,4):
        print(y,end=' ')
    print()
# Out:
# 1 2 3
# 1 2 3
# 1 2 3

# %%
for x in range(1,4):
    for y in range(1,4):
        print(x,end=' ')
    print()
# Out:
# 1 1 1
# 2 2 2
# 3 3 3

# %%
for y in range(1,4):
    for x in range(3):
        print(y+x,end=' ')
    print()
# Out:
# 1 2 3
# 2 3 4
# 3 4 5

# %%
for y in range(1,4):
    for x in range(3):
        print(chr(x+64+y),end=' ')
    print()
# Out:
# A B C
# B C D
# C D E
